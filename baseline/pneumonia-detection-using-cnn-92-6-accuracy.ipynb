# %% [markdown]
# # Baseline model
# Gathered from https://www.kaggle.com/madz2000/pneumonia-detection-using-cnn-92-6-accuracy

# %% [markdown]
# # What is Pneumonia?
# **Pneumonia is an inflammatory condition of the lung affecting primarily the small air sacs known as alveoli.Symptoms typically include some combination of productive or dry cough, chest pain, fever and difficulty breathing. The severity of the condition is variable. Pneumonia is usually caused by infection with viruses or bacteria and less commonly by other microorganisms, certain medications or conditions such as autoimmune diseases.Risk factors include cystic fibrosis, chronic obstructive pulmonary disease (COPD), asthma, diabetes, heart failure, a history of smoking, a poor ability to cough such as following a stroke and a weak immune system. Diagnosis is often based on symptoms and physical examination. Chest X-ray, blood tests, and culture of the sputum may help confirm the diagnosis.The disease may be classified by where it was acquired, such as community- or hospital-acquired or healthcare-associated pneumonia.**
# ![image.png](attachment:image.png)

# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load in 

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the "../input/" directory.
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/hdd/Pioneer/chest-xray-pneumonia'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # Any results you write to the current directory are saved as output.

# %% [markdown]
# # Importing the necessary libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.callbacks import ReduceLROnPlateau
import cv2
import os
import pandas as pd

# %% [markdown]
# # Description of the Pneumonia Dataset
# **The dataset is organized into 3 folders (train, test, val) and contains subfolders for each image category (Pneumonia/Normal). There are 5,863 X-Ray images (JPEG) and 2 categories (Pneumonia/Normal).
# Chest X-ray images (anterior-posterior) were selected from retrospective cohorts of pediatric patients of one to five years old from Guangzhou Women and Children’s Medical Center, Guangzhou. All chest X-ray imaging was performed as part of patients’ routine clinical care.
# For the analysis of chest x-ray images, all chest radiographs were initially screened for quality control by removing all low quality or unreadable scans. The diagnoses for the images were then graded by two expert physicians before being cleared for training the AI system. In order to account for any grading errors, the evaluation set was also checked by a third expert.**

# %%
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150

# %%
# def get_training_data(data_dir):
#     data = [] 
#     for label in labels: 
#         path = os.path.join(data_dir, label)
#         class_num = labels.index(label)
#         print(f'Currently reading: {path}')
#         for img in os.listdir(path):
#             try:
#                 img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
#                 resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
#                 data.append([resized_arr, class_num])
#             except Exception as e:
#                 print(e)
#     return np.array(data)

# %%
# If you've already ran the previous code block, run this one instead.
data = np.load('data.npy', allow_pickle=True)

# %%
# Shuffle dataset
np.random.seed(1337)
np.random.shuffle(data)

# %%
train, val, test = np.split(data, [int(.75*len(data)), int(.80*len(data))])

# %% [markdown]
# # Loading the Dataset

# %%
# train = get_training_data('/hdd/Pioneer/chest-xray-pneumonia/chest_xray/chest_xray/train')
# test = get_training_data('../input/chest-xray-pneumonia/chest_xray/chest_xray/test')
# val = get_training_data('../input/chest-xray-pneumonia/chest_xray/chest_xray/val')

# %% [markdown]
# # Data Visualization & Preprocessing

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("Pneumonia")
    else:
        l.append("Normal")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /home/jack/miniconda3/envs/ml/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %% [markdown]
# **The data seems imbalanced . To increase the no. of training examples, we will use data augmentation**

# %% [markdown]
# **Previewing the images of both the classes**

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[0][0], cmap='gray')
plt.title(labels[train[0][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[-1][0], cmap='gray')
plt.title(labels[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'PNEUMONIA')

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
    
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# %% [markdown]
# **We perform a grayscale normalization to reduce the effect of illumination's differences.Moreover the CNN converges faster on [0..1] data than on [0..255].**

# %%
# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# %%
# resize data for deep learning 
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %% [markdown]
# # Data Augmentation
# **In order to avoid overfitting problem, we need to expand artificially our dataset. We can make your existing dataset even larger. The idea is to alter the training data with small transformations to reproduce the variations.
# Approaches that alter the training data in ways that change the array representation while keeping the label the same are known as data augmentation techniques. Some popular augmentations people use are grayscales, horizontal flips, vertical flips, random crops, color jitters, translations, rotations, and much more.
# By applying just a couple of these transformations to our training data, we can easily double or triple the number of training examples and create a very robust model.**

# %%
# With data augmentation to prevent overfitting and handling the imbalance in dataset

datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %% [markdown]
# For the data augmentation, i choosed to :
# 1. Randomly rotate some training images by 30 degrees
# 2. Randomly Zoom by 20% some training images
# 3. Randomly shift images horizontally by 10% of the width
# 4. Randomly shift images vertically by 10% of the height
# 5. Randomly flip images horizontally.
# Once our model is ready, we fit the training dataset.

# %% [markdown]
# # Training the Model

# %%
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='roc', curve='ROC'), # roc curve
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]
# Out:
# 2021-09-24 23:47:45.174134: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-24 23:47:45.178677: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-24 23:47:45.179074: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-24 23:47:45.179903: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-09-24 23:47:45.180470: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-24 23:47:45.180837: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-24 23:47:45.181185: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-24 23:47:45.527836: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-24 23:47:45.528200: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-24 23:47:45.528536: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-24 23:47:45.528854: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5957 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:0a:00.0, compute capability: 7.5

# %%
model = Sequential()
model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "rmsprop" , loss = 'binary_crossentropy' , metrics = METRICS)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 150, 150, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 75, 75, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 38, 38, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 38, 38, 64)        36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 38, 38, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 19, 19, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 19, 19, 128)       73856
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19, 19, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 19, 19, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 256)       295168
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 10, 256)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 10, 10, 256)       1024
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               819328
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,246,401
# Trainable params: 1,245,313
# Non-trainable params: 1,088
# _________________________________________________________________

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)

# %%
history = model.fit(datagen.flow(x_train,y_train, batch_size = 32) ,epochs = 50 , validation_data = datagen.flow(x_val, y_val) ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/50
# 2021-09-24 23:47:45.820470: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-09-24 23:47:47.633654: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8202
# 138/138 [==============================] - 9s 42ms/step - loss: 0.7050 - tp: 815.0000 - fp: 381.0000 - tn: 2810.0000 - fn: 386.0000 - accuracy: 0.8254 - precision: 0.6814 - recall: 0.6786 - roc: 0.8777 - prc: 0.6573 - val_loss: 5.7572 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 226.0000 - val_fn: 66.0000 - val_accuracy: 0.7740 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_roc: 0.5000 - val_prc: 0.2260
# Epoch 2/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.3065 - tp: 930.0000 - fp: 259.0000 - tn: 2932.0000 - fn: 271.0000 - accuracy: 0.8793 - precision: 0.7822 - recall: 0.7744 - roc: 0.9354 - prc: 0.8366 - val_loss: 2.0736 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 226.0000 - val_fn: 66.0000 - val_accuracy: 0.7740 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_roc: 0.5000 - val_prc: 0.2260
# Epoch 3/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.2938 - tp: 966.0000 - fp: 206.0000 - tn: 2985.0000 - fn: 235.0000 - accuracy: 0.8996 - precision: 0.8242 - recall: 0.8043 - roc: 0.9440 - prc: 0.8662 - val_loss: 2.7494 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 226.0000 - val_fn: 66.0000 - val_accuracy: 0.7740 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_roc: 0.5823 - val_prc: 0.3908
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 4/50
# 138/138 [==============================] - 5s 34ms/step - loss: 0.1882 - tp: 1055.0000 - fp: 150.0000 - tn: 3041.0000 - fn: 146.0000 - accuracy: 0.9326 - precision: 0.8755 - recall: 0.8784 - roc: 0.9721 - prc: 0.9331 - val_loss: 0.3547 - val_tp: 43.0000 - val_fp: 2.0000 - val_tn: 224.0000 - val_fn: 23.0000 - val_accuracy: 0.9144 - val_precision: 0.9556 - val_recall: 0.6515 - val_roc: 0.9404 - val_prc: 0.9005
# Epoch 5/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1862 - tp: 1054.0000 - fp: 134.0000 - tn: 3057.0000 - fn: 147.0000 - accuracy: 0.9360 - precision: 0.8872 - recall: 0.8776 - roc: 0.9727 - prc: 0.9404 - val_loss: 0.3980 - val_tp: 45.0000 - val_fp: 1.0000 - val_tn: 225.0000 - val_fn: 21.0000 - val_accuracy: 0.9247 - val_precision: 0.9783 - val_recall: 0.6818 - val_roc: 0.9343 - val_prc: 0.8946
# Epoch 6/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1644 - tp: 1053.0000 - fp: 109.0000 - tn: 3082.0000 - fn: 148.0000 - accuracy: 0.9415 - precision: 0.9062 - recall: 0.8768 - roc: 0.9774 - prc: 0.9498 - val_loss: 0.9416 - val_tp: 22.0000 - val_fp: 0.0000e+00 - val_tn: 226.0000 - val_fn: 44.0000 - val_accuracy: 0.8493 - val_precision: 1.0000 - val_recall: 0.3333 - val_roc: 0.8788 - val_prc: 0.8463
# Epoch 7/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1677 - tp: 1072.0000 - fp: 97.0000 - tn: 3094.0000 - fn: 129.0000 - accuracy: 0.9485 - precision: 0.9170 - recall: 0.8926 - roc: 0.9780 - prc: 0.9522 - val_loss: 0.2467 - val_tp: 63.0000 - val_fp: 27.0000 - val_tn: 199.0000 - val_fn: 3.0000 - val_accuracy: 0.8973 - val_precision: 0.7000 - val_recall: 0.9545 - val_roc: 0.9728 - val_prc: 0.9105
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Epoch 8/50
# 138/138 [==============================] - 5s 37ms/step - loss: 0.1463 - tp: 1100.0000 - fp: 94.0000 - tn: 3097.0000 - fn: 101.0000 - accuracy: 0.9556 - precision: 0.9213 - recall: 0.9159 - roc: 0.9819 - prc: 0.9596 - val_loss: 0.1438 - val_tp: 61.0000 - val_fp: 13.0000 - val_tn: 213.0000 - val_fn: 5.0000 - val_accuracy: 0.9384 - val_precision: 0.8243 - val_recall: 0.9242 - val_roc: 0.9885 - val_prc: 0.9671
# Epoch 9/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1375 - tp: 1087.0000 - fp: 95.0000 - tn: 3096.0000 - fn: 114.0000 - accuracy: 0.9524 - precision: 0.9196 - recall: 0.9051 - roc: 0.9843 - prc: 0.9652 - val_loss: 0.2967 - val_tp: 64.0000 - val_fp: 29.0000 - val_tn: 197.0000 - val_fn: 2.0000 - val_accuracy: 0.8938 - val_precision: 0.6882 - val_recall: 0.9697 - val_roc: 0.9776 - val_prc: 0.9213
# Epoch 10/50
# 138/138 [==============================] - 5s 37ms/step - loss: 0.1329 - tp: 1080.0000 - fp: 90.0000 - tn: 3101.0000 - fn: 121.0000 - accuracy: 0.9520 - precision: 0.9231 - recall: 0.8993 - roc: 0.9839 - prc: 0.9666 - val_loss: 0.2487 - val_tp: 63.0000 - val_fp: 25.0000 - val_tn: 201.0000 - val_fn: 3.0000 - val_accuracy: 0.9041 - val_precision: 0.7159 - val_recall: 0.9545 - val_roc: 0.9825 - val_prc: 0.9382
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# Epoch 11/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1326 - tp: 1097.0000 - fp: 78.0000 - tn: 3113.0000 - fn: 104.0000 - accuracy: 0.9586 - precision: 0.9336 - recall: 0.9134 - roc: 0.9852 - prc: 0.9657 - val_loss: 0.1808 - val_tp: 53.0000 - val_fp: 2.0000 - val_tn: 224.0000 - val_fn: 13.0000 - val_accuracy: 0.9486 - val_precision: 0.9636 - val_recall: 0.8030 - val_roc: 0.9602 - val_prc: 0.9486
# Epoch 12/50
# 138/138 [==============================] - 5s 37ms/step - loss: 0.1279 - tp: 1087.0000 - fp: 82.0000 - tn: 3109.0000 - fn: 114.0000 - accuracy: 0.9554 - precision: 0.9299 - recall: 0.9051 - roc: 0.9866 - prc: 0.9709 - val_loss: 0.1350 - val_tp: 57.0000 - val_fp: 4.0000 - val_tn: 222.0000 - val_fn: 9.0000 - val_accuracy: 0.9555 - val_precision: 0.9344 - val_recall: 0.8636 - val_roc: 0.9782 - val_prc: 0.9589
# Epoch 13/50
# 138/138 [==============================] - 5s 36ms/step - loss: 0.1198 - tp: 1110.0000 - fp: 87.0000 - tn: 3104.0000 - fn: 91.0000 - accuracy: 0.9595 - precision: 0.9273 - recall: 0.9242 - roc: 0.9871 - prc: 0.9713 - val_loss: 0.0876 - val_tp: 60.0000 - val_fp: 3.0000 - val_tn: 223.0000 - val_fn: 6.0000 - val_accuracy: 0.9692 - val_precision: 0.9524 - val_recall: 0.9091 - val_roc: 0.9915 - val_prc: 0.9789
# Epoch 14/50
# 138/138 [==============================] - 5s 37ms/step - loss: 0.1260 - tp: 1084.0000 - fp: 81.0000 - tn: 3110.0000 - fn: 117.0000 - accuracy: 0.9549 - precision: 0.9305 - recall: 0.9026 - roc: 0.9862 - prc: 0.9696 - val_loss: 0.1343 - val_tp: 62.0000 - val_fp: 15.0000 - val_tn: 211.0000 - val_fn: 4.0000 - val_accuracy: 0.9349 - val_precision: 0.8052 - val_recall: 0.9394 - val_roc: 0.9906 - val_prc: 0.9761
# Epoch 15/50
# 138/138 [==============================] - 5s 37ms/step - loss: 0.1214 - tp: 1103.0000 - fp: 78.0000 - tn: 3113.0000 - fn: 98.0000 - accuracy: 0.9599 - precision: 0.9340 - recall: 0.9184 - roc: 0.9867 - prc: 0.9709 - val_loss: 0.1753 - val_tp: 62.0000 - val_fp: 16.0000 - val_tn: 210.0000 - val_fn: 4.0000 - val_accuracy: 0.9315 - val_precision: 0.7949 - val_recall: 0.9394 - val_roc: 0.9868 - val_prc: 0.9529
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# Epoch 16/50
# 138/138 [==============================] - 5s 36ms/step - loss: 0.1263 - tp: 1103.0000 - fp: 82.0000 - tn: 3109.0000 - fn: 98.0000 - accuracy: 0.9590 - precision: 0.9308 - recall: 0.9184 - roc: 0.9860 - prc: 0.9685 - val_loss: 0.1181 - val_tp: 60.0000 - val_fp: 8.0000 - val_tn: 218.0000 - val_fn: 6.0000 - val_accuracy: 0.9521 - val_precision: 0.8824 - val_recall: 0.9091 - val_roc: 0.9868 - val_prc: 0.9659
# Epoch 17/50
# 138/138 [==============================] - 5s 37ms/step - loss: 0.1223 - tp: 1093.0000 - fp: 89.0000 - tn: 3102.0000 - fn: 108.0000 - accuracy: 0.9551 - precision: 0.9247 - recall: 0.9101 - roc: 0.9871 - prc: 0.9715 - val_loss: 0.1121 - val_tp: 60.0000 - val_fp: 3.0000 - val_tn: 223.0000 - val_fn: 6.0000 - val_accuracy: 0.9692 - val_precision: 0.9524 - val_recall: 0.9091 - val_roc: 0.9864 - val_prc: 0.9683
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# Epoch 18/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1188 - tp: 1097.0000 - fp: 80.0000 - tn: 3111.0000 - fn: 104.0000 - accuracy: 0.9581 - precision: 0.9320 - recall: 0.9134 - roc: 0.9875 - prc: 0.9743 - val_loss: 0.1158 - val_tp: 61.0000 - val_fp: 7.0000 - val_tn: 219.0000 - val_fn: 5.0000 - val_accuracy: 0.9589 - val_precision: 0.8971 - val_recall: 0.9242 - val_roc: 0.9884 - val_prc: 0.9678
# Epoch 19/50
# 138/138 [==============================] - 5s 38ms/step - loss: 0.1276 - tp: 1088.0000 - fp: 96.0000 - tn: 3095.0000 - fn: 113.0000 - accuracy: 0.9524 - precision: 0.9189 - recall: 0.9059 - roc: 0.9853 - prc: 0.9697 - val_loss: 0.1303 - val_tp: 60.0000 - val_fp: 4.0000 - val_tn: 222.0000 - val_fn: 6.0000 - val_accuracy: 0.9658 - val_precision: 0.9375 - val_recall: 0.9091 - val_roc: 0.9801 - val_prc: 0.9646
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 20/50
# 138/138 [==============================] - 5s 36ms/step - loss: 0.1143 - tp: 1099.0000 - fp: 81.0000 - tn: 3110.0000 - fn: 102.0000 - accuracy: 0.9583 - precision: 0.9314 - recall: 0.9151 - roc: 0.9885 - prc: 0.9730 - val_loss: 0.1577 - val_tp: 59.0000 - val_fp: 6.0000 - val_tn: 220.0000 - val_fn: 7.0000 - val_accuracy: 0.9555 - val_precision: 0.9077 - val_recall: 0.8939 - val_roc: 0.9691 - val_prc: 0.9492
# Epoch 21/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1219 - tp: 1108.0000 - fp: 84.0000 - tn: 3107.0000 - fn: 93.0000 - accuracy: 0.9597 - precision: 0.9295 - recall: 0.9226 - roc: 0.9872 - prc: 0.9703 - val_loss: 0.1126 - val_tp: 60.0000 - val_fp: 4.0000 - val_tn: 222.0000 - val_fn: 6.0000 - val_accuracy: 0.9658 - val_precision: 0.9375 - val_recall: 0.9091 - val_roc: 0.9774 - val_prc: 0.9689
# Epoch 22/50
# 138/138 [==============================] - 5s 37ms/step - loss: 0.1265 - tp: 1087.0000 - fp: 78.0000 - tn: 3113.0000 - fn: 114.0000 - accuracy: 0.9563 - precision: 0.9330 - recall: 0.9051 - roc: 0.9850 - prc: 0.9678 - val_loss: 0.1018 - val_tp: 62.0000 - val_fp: 6.0000 - val_tn: 220.0000 - val_fn: 4.0000 - val_accuracy: 0.9658 - val_precision: 0.9118 - val_recall: 0.9394 - val_roc: 0.9849 - val_prc: 0.9713
# Epoch 23/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1097 - tp: 1110.0000 - fp: 81.0000 - tn: 3110.0000 - fn: 91.0000 - accuracy: 0.9608 - precision: 0.9320 - recall: 0.9242 - roc: 0.9892 - prc: 0.9762 - val_loss: 0.1159 - val_tp: 59.0000 - val_fp: 6.0000 - val_tn: 220.0000 - val_fn: 7.0000 - val_accuracy: 0.9555 - val_precision: 0.9077 - val_recall: 0.8939 - val_roc: 0.9868 - val_prc: 0.9662
# Epoch 24/50
# 138/138 [==============================] - 5s 36ms/step - loss: 0.1207 - tp: 1102.0000 - fp: 83.0000 - tn: 3108.0000 - fn: 99.0000 - accuracy: 0.9586 - precision: 0.9300 - recall: 0.9176 - roc: 0.9874 - prc: 0.9719 - val_loss: 0.1283 - val_tp: 61.0000 - val_fp: 5.0000 - val_tn: 221.0000 - val_fn: 5.0000 - val_accuracy: 0.9658 - val_precision: 0.9242 - val_recall: 0.9242 - val_roc: 0.9725 - val_prc: 0.9605
# Epoch 25/50
# 138/138 [==============================] - 5s 36ms/step - loss: 0.1178 - tp: 1098.0000 - fp: 80.0000 - tn: 3111.0000 - fn: 103.0000 - accuracy: 0.9583 - precision: 0.9321 - recall: 0.9142 - roc: 0.9876 - prc: 0.9732 - val_loss: 0.0864 - val_tp: 62.0000 - val_fp: 6.0000 - val_tn: 220.0000 - val_fn: 4.0000 - val_accuracy: 0.9658 - val_precision: 0.9118 - val_recall: 0.9394 - val_roc: 0.9931 - val_prc: 0.9809
# Epoch 26/50
# 138/138 [==============================] - 5s 37ms/step - loss: 0.1197 - tp: 1103.0000 - fp: 78.0000 - tn: 3113.0000 - fn: 98.0000 - accuracy: 0.9599 - precision: 0.9340 - recall: 0.9184 - roc: 0.9869 - prc: 0.9738 - val_loss: 0.1106 - val_tp: 61.0000 - val_fp: 4.0000 - val_tn: 222.0000 - val_fn: 5.0000 - val_accuracy: 0.9692 - val_precision: 0.9385 - val_recall: 0.9242 - val_roc: 0.9768 - val_prc: 0.9676
# Epoch 27/50
# 138/138 [==============================] - 5s 36ms/step - loss: 0.1159 - tp: 1097.0000 - fp: 81.0000 - tn: 3110.0000 - fn: 104.0000 - accuracy: 0.9579 - precision: 0.9312 - recall: 0.9134 - roc: 0.9892 - prc: 0.9748 - val_loss: 0.0924 - val_tp: 60.0000 - val_fp: 2.0000 - val_tn: 224.0000 - val_fn: 6.0000 - val_accuracy: 0.9726 - val_precision: 0.9677 - val_recall: 0.9091 - val_roc: 0.9909 - val_prc: 0.9764
# Epoch 28/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1216 - tp: 1101.0000 - fp: 82.0000 - tn: 3109.0000 - fn: 100.0000 - accuracy: 0.9586 - precision: 0.9307 - recall: 0.9167 - roc: 0.9877 - prc: 0.9727 - val_loss: 0.1082 - val_tp: 59.0000 - val_fp: 6.0000 - val_tn: 220.0000 - val_fn: 7.0000 - val_accuracy: 0.9555 - val_precision: 0.9077 - val_recall: 0.8939 - val_roc: 0.9892 - val_prc: 0.9714
# Epoch 29/50
# 138/138 [==============================] - 5s 36ms/step - loss: 0.1150 - tp: 1107.0000 - fp: 83.0000 - tn: 3108.0000 - fn: 94.0000 - accuracy: 0.9597 - precision: 0.9303 - recall: 0.9217 - roc: 0.9887 - prc: 0.9758 - val_loss: 0.1179 - val_tp: 60.0000 - val_fp: 8.0000 - val_tn: 218.0000 - val_fn: 6.0000 - val_accuracy: 0.9521 - val_precision: 0.8824 - val_recall: 0.9091 - val_roc: 0.9834 - val_prc: 0.9699
# Epoch 30/50
# 138/138 [==============================] - 5s 36ms/step - loss: 0.1281 - tp: 1080.0000 - fp: 80.0000 - tn: 3111.0000 - fn: 121.0000 - accuracy: 0.9542 - precision: 0.9310 - recall: 0.8993 - roc: 0.9867 - prc: 0.9688 - val_loss: 0.1128 - val_tp: 58.0000 - val_fp: 5.0000 - val_tn: 221.0000 - val_fn: 8.0000 - val_accuracy: 0.9555 - val_precision: 0.9206 - val_recall: 0.8788 - val_roc: 0.9834 - val_prc: 0.9684
# Epoch 31/50
# 138/138 [==============================] - 5s 36ms/step - loss: 0.1233 - tp: 1100.0000 - fp: 76.0000 - tn: 3115.0000 - fn: 101.0000 - accuracy: 0.9597 - precision: 0.9354 - recall: 0.9159 - roc: 0.9870 - prc: 0.9727 - val_loss: 0.1011 - val_tp: 60.0000 - val_fp: 3.0000 - val_tn: 223.0000 - val_fn: 6.0000 - val_accuracy: 0.9692 - val_precision: 0.9524 - val_recall: 0.9091 - val_roc: 0.9891 - val_prc: 0.9728
# Epoch 32/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1154 - tp: 1096.0000 - fp: 77.0000 - tn: 3114.0000 - fn: 105.0000 - accuracy: 0.9586 - precision: 0.9344 - recall: 0.9126 - roc: 0.9885 - prc: 0.9716 - val_loss: 0.1317 - val_tp: 61.0000 - val_fp: 5.0000 - val_tn: 221.0000 - val_fn: 5.0000 - val_accuracy: 0.9658 - val_precision: 0.9242 - val_recall: 0.9242 - val_roc: 0.9817 - val_prc: 0.9647
# Epoch 33/50
# 138/138 [==============================] - 5s 36ms/step - loss: 0.1177 - tp: 1094.0000 - fp: 84.0000 - tn: 3107.0000 - fn: 107.0000 - accuracy: 0.9565 - precision: 0.9287 - recall: 0.9109 - roc: 0.9879 - prc: 0.9735 - val_loss: 0.0912 - val_tp: 60.0000 - val_fp: 7.0000 - val_tn: 219.0000 - val_fn: 6.0000 - val_accuracy: 0.9555 - val_precision: 0.8955 - val_recall: 0.9091 - val_roc: 0.9922 - val_prc: 0.9785
# Epoch 34/50
# 138/138 [==============================] - 5s 36ms/step - loss: 0.1179 - tp: 1099.0000 - fp: 85.0000 - tn: 3106.0000 - fn: 102.0000 - accuracy: 0.9574 - precision: 0.9282 - recall: 0.9151 - roc: 0.9884 - prc: 0.9736 - val_loss: 0.1176 - val_tp: 59.0000 - val_fp: 5.0000 - val_tn: 221.0000 - val_fn: 7.0000 - val_accuracy: 0.9589 - val_precision: 0.9219 - val_recall: 0.8939 - val_roc: 0.9863 - val_prc: 0.9660
# Epoch 35/50
# 138/138 [==============================] - 5s 37ms/step - loss: 0.1211 - tp: 1106.0000 - fp: 89.0000 - tn: 3102.0000 - fn: 95.0000 - accuracy: 0.9581 - precision: 0.9255 - recall: 0.9209 - roc: 0.9869 - prc: 0.9697 - val_loss: 0.1104 - val_tp: 60.0000 - val_fp: 5.0000 - val_tn: 221.0000 - val_fn: 6.0000 - val_accuracy: 0.9623 - val_precision: 0.9231 - val_recall: 0.9091 - val_roc: 0.9820 - val_prc: 0.9690
# Epoch 36/50
# 138/138 [==============================] - 5s 36ms/step - loss: 0.1193 - tp: 1112.0000 - fp: 72.0000 - tn: 3119.0000 - fn: 89.0000 - accuracy: 0.9633 - precision: 0.9392 - recall: 0.9259 - roc: 0.9866 - prc: 0.9696 - val_loss: 0.1365 - val_tp: 61.0000 - val_fp: 5.0000 - val_tn: 221.0000 - val_fn: 5.0000 - val_accuracy: 0.9658 - val_precision: 0.9242 - val_recall: 0.9242 - val_roc: 0.9738 - val_prc: 0.9611
# Epoch 37/50
# 138/138 [==============================] - 5s 36ms/step - loss: 0.1286 - tp: 1092.0000 - fp: 89.0000 - tn: 3102.0000 - fn: 109.0000 - accuracy: 0.9549 - precision: 0.9246 - recall: 0.9092 - roc: 0.9860 - prc: 0.9674 - val_loss: 0.1324 - val_tp: 59.0000 - val_fp: 5.0000 - val_tn: 221.0000 - val_fn: 7.0000 - val_accuracy: 0.9589 - val_precision: 0.9219 - val_recall: 0.8939 - val_roc: 0.9682 - val_prc: 0.9594
# Epoch 38/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1232 - tp: 1101.0000 - fp: 84.0000 - tn: 3107.0000 - fn: 100.0000 - accuracy: 0.9581 - precision: 0.9291 - recall: 0.9167 - roc: 0.9870 - prc: 0.9725 - val_loss: 0.1088 - val_tp: 58.0000 - val_fp: 3.0000 - val_tn: 223.0000 - val_fn: 8.0000 - val_accuracy: 0.9623 - val_precision: 0.9508 - val_recall: 0.8788 - val_roc: 0.9830 - val_prc: 0.9684
# Epoch 39/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1307 - tp: 1098.0000 - fp: 86.0000 - tn: 3105.0000 - fn: 103.0000 - accuracy: 0.9570 - precision: 0.9274 - recall: 0.9142 - roc: 0.9849 - prc: 0.9671 - val_loss: 0.1305 - val_tp: 59.0000 - val_fp: 4.0000 - val_tn: 222.0000 - val_fn: 7.0000 - val_accuracy: 0.9623 - val_precision: 0.9365 - val_recall: 0.8939 - val_roc: 0.9739 - val_prc: 0.9612
# Epoch 40/50
# 138/138 [==============================] - 5s 37ms/step - loss: 0.1157 - tp: 1096.0000 - fp: 75.0000 - tn: 3116.0000 - fn: 105.0000 - accuracy: 0.9590 - precision: 0.9360 - recall: 0.9126 - roc: 0.9884 - prc: 0.9761 - val_loss: 0.1066 - val_tp: 59.0000 - val_fp: 3.0000 - val_tn: 223.0000 - val_fn: 7.0000 - val_accuracy: 0.9658 - val_precision: 0.9516 - val_recall: 0.8939 - val_roc: 0.9875 - val_prc: 0.9696
# Epoch 41/50
# 138/138 [==============================] - 5s 37ms/step - loss: 0.1240 - tp: 1091.0000 - fp: 83.0000 - tn: 3108.0000 - fn: 110.0000 - accuracy: 0.9561 - precision: 0.9293 - recall: 0.9084 - roc: 0.9849 - prc: 0.9684 - val_loss: 0.1033 - val_tp: 61.0000 - val_fp: 3.0000 - val_tn: 223.0000 - val_fn: 5.0000 - val_accuracy: 0.9726 - val_precision: 0.9531 - val_recall: 0.9242 - val_roc: 0.9883 - val_prc: 0.9726
# Epoch 42/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1244 - tp: 1097.0000 - fp: 76.0000 - tn: 3115.0000 - fn: 104.0000 - accuracy: 0.9590 - precision: 0.9352 - recall: 0.9134 - roc: 0.9865 - prc: 0.9727 - val_loss: 0.1081 - val_tp: 60.0000 - val_fp: 6.0000 - val_tn: 220.0000 - val_fn: 6.0000 - val_accuracy: 0.9589 - val_precision: 0.9091 - val_recall: 0.9091 - val_roc: 0.9835 - val_prc: 0.9696
# Epoch 43/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1222 - tp: 1096.0000 - fp: 77.0000 - tn: 3114.0000 - fn: 105.0000 - accuracy: 0.9586 - precision: 0.9344 - recall: 0.9126 - roc: 0.9864 - prc: 0.9734 - val_loss: 0.1053 - val_tp: 60.0000 - val_fp: 9.0000 - val_tn: 217.0000 - val_fn: 6.0000 - val_accuracy: 0.9486 - val_precision: 0.8696 - val_recall: 0.9091 - val_roc: 0.9898 - val_prc: 0.9725
# Epoch 44/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1235 - tp: 1091.0000 - fp: 80.0000 - tn: 3111.0000 - fn: 110.0000 - accuracy: 0.9567 - precision: 0.9317 - recall: 0.9084 - roc: 0.9867 - prc: 0.9696 - val_loss: 0.1006 - val_tp: 61.0000 - val_fp: 5.0000 - val_tn: 221.0000 - val_fn: 5.0000 - val_accuracy: 0.9658 - val_precision: 0.9242 - val_recall: 0.9242 - val_roc: 0.9840 - val_prc: 0.9741
# Epoch 45/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1099 - tp: 1118.0000 - fp: 69.0000 - tn: 3122.0000 - fn: 83.0000 - accuracy: 0.9654 - precision: 0.9419 - recall: 0.9309 - roc: 0.9892 - prc: 0.9743 - val_loss: 0.1050 - val_tp: 61.0000 - val_fp: 4.0000 - val_tn: 222.0000 - val_fn: 5.0000 - val_accuracy: 0.9692 - val_precision: 0.9385 - val_recall: 0.9242 - val_roc: 0.9816 - val_prc: 0.9707
# Epoch 46/50
# 138/138 [==============================] - 5s 36ms/step - loss: 0.1232 - tp: 1097.0000 - fp: 80.0000 - tn: 3111.0000 - fn: 104.0000 - accuracy: 0.9581 - precision: 0.9320 - recall: 0.9134 - roc: 0.9861 - prc: 0.9694 - val_loss: 0.1331 - val_tp: 60.0000 - val_fp: 3.0000 - val_tn: 223.0000 - val_fn: 6.0000 - val_accuracy: 0.9692 - val_precision: 0.9524 - val_recall: 0.9091 - val_roc: 0.9721 - val_prc: 0.9570
# Epoch 47/50
# 138/138 [==============================] - 5s 36ms/step - loss: 0.1263 - tp: 1091.0000 - fp: 78.0000 - tn: 3113.0000 - fn: 110.0000 - accuracy: 0.9572 - precision: 0.9333 - recall: 0.9084 - roc: 0.9871 - prc: 0.9693 - val_loss: 0.0859 - val_tp: 61.0000 - val_fp: 5.0000 - val_tn: 221.0000 - val_fn: 5.0000 - val_accuracy: 0.9658 - val_precision: 0.9242 - val_recall: 0.9242 - val_roc: 0.9932 - val_prc: 0.9817
# Epoch 48/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1238 - tp: 1115.0000 - fp: 86.0000 - tn: 3105.0000 - fn: 86.0000 - accuracy: 0.9608 - precision: 0.9284 - recall: 0.9284 - roc: 0.9859 - prc: 0.9694 - val_loss: 0.1200 - val_tp: 58.0000 - val_fp: 8.0000 - val_tn: 218.0000 - val_fn: 8.0000 - val_accuracy: 0.9452 - val_precision: 0.8788 - val_recall: 0.8788 - val_roc: 0.9860 - val_prc: 0.9652
# Epoch 49/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1234 - tp: 1105.0000 - fp: 88.0000 - tn: 3103.0000 - fn: 96.0000 - accuracy: 0.9581 - precision: 0.9262 - recall: 0.9201 - roc: 0.9864 - prc: 0.9679 - val_loss: 0.1293 - val_tp: 58.0000 - val_fp: 5.0000 - val_tn: 221.0000 - val_fn: 8.0000 - val_accuracy: 0.9555 - val_precision: 0.9206 - val_recall: 0.8788 - val_roc: 0.9846 - val_prc: 0.9608
# Epoch 50/50
# 138/138 [==============================] - 5s 35ms/step - loss: 0.1257 - tp: 1087.0000 - fp: 84.0000 - tn: 3107.0000 - fn: 114.0000 - accuracy: 0.9549 - precision: 0.9283 - recall: 0.9051 - roc: 0.9861 - prc: 0.9681 - val_loss: 0.0994 - val_tp: 62.0000 - val_fp: 4.0000 - val_tn: 222.0000 - val_fn: 4.0000 - val_accuracy: 0.9726 - val_precision: 0.9394 - val_recall: 0.9394 - val_roc: 0.9841 - val_prc: 0.9733

# %%
model.save('../saved_models/baseline')
# Out:
# 2021-09-24 23:51:59.640029: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ../saved_models/baseline/assets

# %%
results = model.evaluate(x_test,y_test)
# Out:
# 37/37 [==============================] - 1s 12ms/step - loss: 0.3208 - tp: 309.0000 - fp: 107.0000 - tn: 749.0000 - fn: 7.0000 - accuracy: 0.9027 - precision: 0.7428 - recall: 0.9778 - roc: 0.9806 - prc: 0.9458

# %%
print("Loss of the model is - " , results[0])
print("True positives of the model is - " , results[1])
print("False positives of the model is - " , results[2])
print("True negatives of the model is - " , results[3])
print("False negatives of the model is - " , results[4])
print("Accuracy of the model is - " , results[5]*100 , "%")
print("Precision of the model is - " , results[6])
print("Recall of the model is - " , results[7])
print("ROC_AUC of the model is - " , results[8])
print("PRC_AUC of the model is - " , results[9])
# Out:
# Loss of the model is -  0.32084912061691284
# True positives of the model is -  309.0
# False positives of the model is -  107.0
# True negatives of the model is -  749.0
# False negatives of the model is -  7.0
# Accuracy of the model is -  90.27303457260132 %
# Precision of the model is -  0.7427884340286255
# Recall of the model is -  0.9778481125831604
# ROC_AUC of the model is -  0.9806337356567383
# PRC_AUC of the model is -  0.9457724094390869

# %% [markdown]
# # Analysis after Model Training

# %%
epochs = [i for i in range(50)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'r-o' , label = 'Validation Loss')
ax[1].set_title('Testing Accuracy & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Training & Validation Loss")
plt.show()

# %%
predictions = (model.predict(x_test) > 0.5).astype("int32")
predictions = predictions.reshape(1,-1)[0]

# %%
from sklearn.metrics import f1_score
f1_score(y_test, predictions)
# Out:
# 0.8442622950819673

# %%
print(classification_report(y_test, predictions, target_names = ['Pneumonia (Class 0)','Normal (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
# Pneumonia (Class 0)       0.99      0.88      0.93       856
#    Normal (Class 1)       0.74      0.98      0.84       316
#
#            accuracy                           0.90      1172
#           macro avg       0.87      0.93      0.89      1172
#        weighted avg       0.92      0.90      0.91      1172

# %%
cm = confusion_matrix(y_test,predictions)
cm
# Out:
# array([[749, 107],
#        [  7, 309]])

# %%
cm = pd.DataFrame(cm , index = ['0','1'] , columns = ['0','1'])

# %%
plt.figure(figsize = (10,10))
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='',xticklabels = labels,yticklabels = labels)
# Out:
# <AxesSubplot:>

# %%
correct = np.nonzero(predictions == y_test)[0]
incorrect = np.nonzero(predictions != y_test)[0]

# %% [markdown]
# **Some of the Correctly Predicted Classes**

# %%
i = 0
for c in correct[:6]:
    plt.subplot(3,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_test[c].reshape(150,150), cmap="gray", interpolation='none')
    plt.title("Predicted Class {},Actual Class {}".format(predictions[c], y_test[c]))
    plt.tight_layout()
    i += 1

# %% [markdown]
# **Some of the Incorrectly Predicted Classes**

# %%
i = 0
for c in incorrect[:6]:
    plt.subplot(3,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_test[c].reshape(150,150), cmap="gray", interpolation='none')
    plt.title("Predicted Class {},Actual Class {}".format(predictions[c], y_test[c]))
    plt.tight_layout()
    i += 1

# %%
def plot_metrics(history):
    
    fig = plt.gcf()
    fig.set_size_inches(20, 3 * 4)

    metrics = ['roc','accuracy','loss', 'prc', 'precision', 'recall']
    for n, metric in enumerate(metrics):
        lims = {'loss': {0,2}}
        name = metric.replace("_"," ").capitalize()
        sp = plt.subplot(2, 3, n + 1)
        plt.plot(history.epoch, history.history[metric], color='C0', label='Train')
        plt.plot(history.epoch, history.history['val_'+metric],
                 color='C1', linestyle="--", label='Val')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        if metric in lims:
            plt.ylim(lims[metric])

        plt.legend()
        
plot_metrics(history)
